# %% [markdown]
# <font color='blue'> **NO** </font>

# %%
import flopy ;import matplotlib.pyplot as plt ;import numpy as np ;from flopy.discretization import StructuredGrid ; from pathlib import Path
import pandas as pd ;from flopy.utils.gridintersect import GridIntersect ;from shapely.geometry import LineString, Polygon; import gisutils 
from flopy.plot import styles ; import earthpy.spatial as es ;import geopandas as gpd ;import rioxarray as rxr ;import rasterio as rio
from rasterio.plot import plotting_extent ;import earthpy.plot as ep ; from pandas import * ;import os;from typing import List, Tuple, Union
