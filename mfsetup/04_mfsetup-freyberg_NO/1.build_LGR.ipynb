# %%
# %%capture
import os   ; import numpy as np    ; import pandas as pd   ; from scipy.interpolate import griddata    ; import matplotlib.pyplot as plt ; from matplotlib import patheffects 
import flopy    ; import flopy.utils.binaryfile as bf   ; from mfsetup import MF6model  ; from mfsetup.discretization import cellids_to_kij ; from gisutils import df2shp
import mfexport ; from mfexport.utils import get_water_table   # ; from pathlib import Path ; TA=Path("./TA");TA.mkdir(exist_ok=True)

# %%
import mfsetup
m = mfsetup.MF6model.setup_from_yaml('freyberg_parent.yml')
# Out:
# loading configuration file freyberg_parent.yml...
#
# Setting up freyberg_lgr_parent model from configuration in freyberg_parent.yml
#
# validating configuration...
# DIS package
# done with validation.
#
# setting up model grid...
# wrote e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_lgr\freyberg_lgr_parent_grid.json
# finished in 0.03s
#
# loading configuration file e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_inset.yml...
#
# Setting up DIS package...
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\top.tif...
# finished in 0.04s
# wrote .\.\freyberg_lgr_parent_top.dat, took 0.00s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\botm_lay0.tif...
# finished in 0.01s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\botm_lay1.tif...
# finished in 0.00s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\botm_lay2.tif...
# finished in 0.00s
# loading .\.\freyberg_lgr_parent_top.dat, shape=(40, 20), took 0.00s
# computing cell thicknesses...
# finished in 0.02s
#
# wrote .\.\freyberg_lgr_parent_botm_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_botm_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_botm_002.dat, took 0.00s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\idomain_lay0.tif...
# finished in 0.05s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\idomain_lay1.tif...
# finished in 0.05s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\idomain_lay2.tif...
# finished in 0.05s
# wrote .\.\freyberg_lgr_parent_idomain_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_002.dat, took 0.00s
# (re)setting the idomain array...
# computing cell thicknesses...
# finished in 0.02s
#
# loading .\.\freyberg_lgr_parent_top.dat, shape=(40, 20), took 0.00s
# computing cell thicknesses...
# finished in 0.02s
#
# wrote .\.\freyberg_lgr_parent_botm_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_botm_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_botm_002.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_002.dat, took 0.00s
# setting up model grid...
# wrote e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_lgr\freyberg_lgr_parent_grid.json
# finished in 0.01s
#
# loading configuration file e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_inset.yml...
# wrote .\.\freyberg_lgr_parent_irch.dat, took 0.00s
# finished in 0.51s
#
#
# validating configuration...
# DIS package
# done with validation.
#
# setting up model grid...
# wrote e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_lgr\freyberg_lgr_inset_grid.json
# finished in 0.04s
#
# wrote .\.\freyberg_lgr_parent_top.dat, took 0.00s
# (re)setting the idomain array...
# computing cell thicknesses...
# finished in 0.02s
#
# loading .\.\freyberg_lgr_parent_top.dat, shape=(40, 20), took 0.00s
# computing cell thicknesses...
# finished in 0.02s
#
# wrote .\.\freyberg_lgr_parent_botm_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_botm_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_botm_002.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_idomain_002.dat, took 0.00s
# setting up model grid...
# wrote e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_lgr\freyberg_lgr_parent_grid.json
# finished in 0.01s
#
# loading configuration file e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_inset.yml...
# wrote .\.\freyberg_lgr_parent_irch.dat, took 0.00s
#
# Setting up TDIS package...
# finished in 0.00s
#
#
# Setting up IMS package...
# finished in 0.00s
#
#
# Setting up IC package...
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\strt_lay0.tif...
# finished in 0.01s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\strt_lay1.tif...
# finished in 0.00s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\strt_lay2.tif...
# finished in 0.00s
# wrote .\.\freyberg_lgr_parent_strt_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_strt_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_parent_strt_002.dat, took 0.00s
# finished in 0.03s
#
#
# Setting up NPF package...
# No data were specified for npf package, variable k
# No data were specified for npf package, variable k33
# finished in 0.00s
#
#
# Setting up STO package...
# No data were specified for sto package, variable sy
# No data were specified for sto package, variable ss
# finished in 0.00s
#
#
# Setting up OC package...
# finished in 0.00s
#
#
# Setting up DIS package...
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\top.tif...
# finished in 0.01s
# wrote .\.\freyberg_lgr_inset_top.dat, took 0.00s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\botm_lay0.tif...
# finished in 0.01s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\botm_lay1.tif...
# finished in 0.01s
# reading data from e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\orig_mf6\postproc\rasters\botm_lay2.tif...
# finished in 0.01s
# loading .\.\freyberg_lgr_inset_top.dat, shape=(150, 80), took 0.01s
# computing cell thicknesses...
# finished in 0.34s
#
# wrote .\.\freyberg_lgr_inset_botm_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_botm_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_botm_002.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_idomain_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_idomain_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_idomain_002.dat, took 0.00s
# (re)setting the idomain array...
# computing cell thicknesses...
# finished in 0.34s
#
# loading .\.\freyberg_lgr_inset_top.dat, shape=(150, 80), took 0.01s
# computing cell thicknesses...
# finished in 0.34s
#
# wrote .\.\freyberg_lgr_inset_botm_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_botm_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_botm_002.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_idomain_000.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_idomain_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_idomain_002.dat, took 0.00s
# setting up model grid...
# wrote e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_lgr\freyberg_lgr_inset_grid.json
# finished in 0.01s
#
# wrote .\.\freyberg_lgr_inset_irch.dat, took 0.00s
# finished in 2.12s
#
#
# Setting up IC package...
# getting i, j locations...
# finished in 0.00s
#
# wrote .\.\freyberg_lgr_inset_strt_000.dat, took 0.01s
# wrote .\.\freyberg_lgr_inset_strt_001.dat, took 0.00s
# wrote .\.\freyberg_lgr_inset_strt_002.dat, took 0.00s
# finished in 0.10s
#
#
# Setting up NPF package...
# No data were specified for npf package, variable k
# No data were specified for npf package, variable k33
# finished in 0.00s
#
#
# Setting up STO package...
# wrote .\.\freyberg_lgr_inset_sy_000.dat, took 0.01s
# wrote .\.\freyberg_lgr_inset_sy_001.dat, took 0.01s
# wrote .\.\freyberg_lgr_inset_sy_002.dat, took 0.01s
# wrote .\.\freyberg_lgr_inset_ss_000.dat, took 0.01s
# wrote .\.\freyberg_lgr_inset_ss_001.dat, took 0.01s
# wrote .\.\freyberg_lgr_inset_ss_002.dat, took 0.01s
# finished in 0.24s
#
#
# Setting up OC package...
# finished in 0.00s
#
#
# Setting up the simulation water mover package...
# no packages with mover information
#
# finished setting up model in 3.85s
# e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_lgr
#
# freyberg_lgr_parent model version 0.post69.dev0+g5e43358
# 3 layer(s), 40 row(s), 20 column(s)
# delr: [250.00...250.00] undefined
# delc: [250.00...250.00] undefined
# CRS: EPSG:2821
# length units: meters
# xll: 564939.1369142552; yll: 6280887.573219389; rotation: 0.0
# Bounds: (np.float64(564939.1369142552), np.float64(569939.1369142552), np.float64(6280887.573219389), np.float64(6290887.573219389))
# Packages: dis ic npf sto oc
# 37 period(s):
#  per start_datetime end_datetime  perlen  steady  nstp
#    0     2020-01-01   2020-01-01     1.0    True     1
#    1     2020-01-01   2020-02-01    31.0   False     1
#    2     2020-02-01   2020-03-01    29.0   False     1
#    ...
#   36     2022-12-01   2022-12-31    30.0   False     1

# %%
m.write_input()
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing package freyberg_lgr.gwfgwf...
#   writing model freyberg_lgr_parent...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package npf...
#     writing package sto...
#     writing package oc...
#   writing model freyberg_lgr_inset...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package npf...
#     writing package sto...
#     writing package oc...
# e:\15_REPOS\02_Beta-Me\mfsetup\mfsetup-freyberg\freyberg_lgr

# %%
m.simulation.run_simulation()
# Out:
# FloPy is using the following executable to run the model: C:\Users\gross.DESKTOP-AIRQM2M\anaconda3\Scripts\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.6.1 02/10/2025
#
#    MODFLOW 6 compiled Feb 14 2025 13:40:10 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  MODFLOW runs in SEQUENTIAL mode
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2025/11/21 17:18:31
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#
# ERROR REPORT:
#
#   1. Input name "FREYBERG_LGR_PARENT" exceeds maximum allowed length (16) for
#      MODELNAME.
#
# UNIT ERROR REPORT:
#
#   1. ERROR OCCURRED WHILE READING FILE 'mfsim.nam'
# (False, [])
