# %% [markdown]
# <font color='blue'> **0.5_merge_parent_models** </font>

# %%
import os; import numpy as np ; import pandas as pd ; import rasterio  ; from rasterio.plot import show  ; from rasterio.merge import merge ; import geopandas as gp ; from pyproj import CRS
from pathlib import Path ; import openpyxl ; import matplotlib.pyplot as plt ; import mfexport  ; import sys ; sys.path.append('../python_packages_static') ; import flopy as fp    
TA=Path("./TA");TB=Path("./TB");TC=Path("./TC")                              ; TD=Path("./TD");TD.mkdir(exist_ok=True)

# %%
PQ = Path('E:/15_REPOS/06')                                                                  # https://water.usgs.gov/GIS/metadata/usgswrd/XML/zell2020_wrr.xml
parent_models = ['0108_0110_0202_0203_MF6_SS_Unconfined_250','0204_0206_0209_MF6_SS_Unconfined_250']

packages = os.listdir(os.path.join(PQ, parent_models[0]))

# %%
def model_raster_data_merge(PQ, TD, parent_models, packages):    
    #  get list of tif files from the models to merge
    for pkg in packages:    

        print('Now merging {} package data'.format(pkg))
        package_tifs = []

        for root, dirs, files in os.walk(os.path.join(PQ, parent_models[0], pkg)):
            for file in files:
                if file.endswith('.tif'):
                    package_tifs.append(file)

        for tif in package_tifs:
            src_files_to_merge = []
            for model in parent_models:
                file_path = os.path.join(PQ, model, pkg, 'rasters', tif)
                
                #  open file in read mode w/rasterio and make a list of files to merge
                src = rasterio.open(file_path)
                src_files_to_merge.append(src)

            #  define nondata value by layer
            if tif.startswith('idomain'):
                nodata = 0
            elif tif.startswith(('hds', 'wt')):
                nodata = np.nan
            else:
                nodata = -2.14748365e+09
            print('nodata value: {}'.format(nodata))
            
            #  perform merge with rasterio.merge.merge
            mosaic, out_trans = merge(src_files_to_merge, nodata=nodata)
            print('merged: {}'.format(tif))
            
            #  plot merged layer to make sure that it looks right
            plot_mosaic = mosaic.copy()
            if not tif.startswith('idomain'):
                plot_mosaic[plot_mosaic==nodata] = np.nan
            plt.figure(figsize=(6, 6))
            plt.imshow(plot_mosaic[0])
            plt.colorbar()
            #plt.show()
            
            #  update the metadata with new dimensions, transform and CRS. Also add compression 'lzw'
            out_meta = src.meta.copy()
            out_meta.update({'driver': 'GTiff',
                     'height': mosaic.shape[1],
                     'width': mosaic.shape[2],
                     'transform': out_trans,
                     'compress': 'lzw',  # see if this works or not...
                     'crs': '+datum=WGS84 +lat_0=23 +lat_1=29.5 +lat_2=45.5 +lon_0=-96 +no_defs +proj=aea +units=m +x_0=0 +y_0=0'
                     }
                    )

            #  write mosaic to TD
            out_fp = os.path.join(TD, (tif[:-4] + '_merged.tif'))

            with rasterio.open(out_fp, "w", **out_meta) as dest:
                dest.write(mosaic)
            
            print('wrote file: {}'.format(out_fp))
            plt.show()

# %%
model_raster_data_merge(PQ, TD, parent_models, packages)
# Out:
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.bat package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.bottoms package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.chd package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.dis package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.drn package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.ghb.ghb-nlcd package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.hds.ascii package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.ic package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.idomain package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.ims package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.nam package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.npf package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.oc package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.rch package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.startheads package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.tdis package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250.top package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250_1.hk package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250_1.hk.update package data
# Now merging 0108_0110_0202_0203_MF6_SS_Unconfined_250_1.rch package data
# Now merging mfsim.nam package data
# Now merging usgs.model.reference package data

# %%
model_ws = os.path.join(TD, 'parent_mf_nwt')                            ; precision = 'double'  ; dtype = np.float64            #parent_models[0]#.dis#.nlay
mf = fp.modflow.Modflow(modelname='ngwm_parent',model_ws=model_ws)      ; dis = fp.modflow.ModflowDis(mf, nlay=3, nrow=50, ncol=50, delr=3, delc=3)

# %%
'''with rasterio.open(os.path.join(TD, 'hds_lay0_per0_stp0_merged.tif')) as src:
    data = np.squeeze(src.read())
plt.imshow(data)    ; plt.show()'''
# Out:
# "with rasterio.open(os.path.join(TD, 'hds_lay0_per0_stp0_merged.tif')) as src:\n    data = np.squeeze(src.read())\n\nplt.imshow(data)\nplt.show()"

# %% [markdown]
# replace `nan` nodata with -9999 values

# %%
data[np.isnan(data)] = -9999
plt.imshow(data)
plt.colorbar()
plt.show()

# %%
text = 'head'

# write a binary data file
pertim = dtype(1.0)
header = flopy.utils.BinaryHeader.create(bintype=text, precision=precision,
                                         text=text, nrow=nrow, ncol=ncol,
                                         ilay=1, pertim=pertim,
                                         totim=pertim, kstp=1, kper=1)
pth = os.path.join(model_ws, 'ngwm_parent.hds')
flopy.utils.Util2d.write_bin(data.shape, pth, data, header_data=header)

# %%
mf.write_input()

# %% [markdown]
# ### write a fake CBC file to make mfsetup happy

# %%
with open(pth.replace('hds','cbc'), 'w') as ofp:
    ofp.write('This is not the file you are looking for \n')

# %%
hdobj = flopy.utils.binaryfile.HeadFile(pth)

# %%
all_kstpkper = hdobj.get_kstpkper()

# %%
last_steps = {kper: kstp for kstp, kper in all_kstpkper}

# %%
last_steps

# %%
mf.dis.nstp.array

# %%
mf.dis.nper

# %%
# for inset_per, parent_per in self.inset_parent_period_mapping.items():

# %% [markdown]
# ### update `nam` file with spatial reference information

# %% [markdown]
# establish relevant information for parent `.nam` file spatial reference header

# %%
merge_dir = '../parent_model/merged_parent_output/'
file_name = 'idomain_lay0_merged.tif'
input_file = os.path.join(merge_dir, file_name)

# %%
with rasterio.open(input_file) as src:
    meta = src.meta
    bounds = src.bounds

# %%
ncol = meta['width']
nlay = meta['count']
nrow = meta['height']
delc = meta['transform'][0]
delr = -meta['transform'][4]
length_units = 'meters'

# parent grid?
xoff = bounds[0]
yoff = bounds[1]
#  coord ref doesn't match epsg code
proj_string = CRS(meta['crs']).to_proj4()
wkt_string = CRS(meta['crs']).to_wkt()

print('ncol: {0}, nlay: {1}, nrow: {2}, delc: {3}, delr: {4}, length_units: {5}, xoff: {6}, yoff: {7}'.format(ncol, nlay, nrow, delc, delr, length_units, xoff, yoff))

# %% [markdown]
# ### re-write name file header to include spatial reference information

# %%
nam= [i.strip() for i in open(os.path.join(model_ws,'ngwm_parent.nam'), 'r').readlines() if '#' not in i]
print (nam)

# %%
headerline = ''.join(['#parent nam file just for reading in hds info\n',
      '#xll:{0}; yll:{1}; rotation:0; proj4_str:{2}; units:meters; lenuni:2;  ;start_datetime:1-1-2011'.format(
      xoff, yoff, '+init=epsg:5070')])

# %%
headerline

# %%
with open(os.path.join(model_ws,'ngwm_parent.nam'), 'w') as ofp:
    ofp.write('{}\n'.format(headerline))
    [ofp.write('{}\n'.format(line)) for line in nam]
