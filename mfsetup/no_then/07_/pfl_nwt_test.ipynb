# %% [markdown]
# <font color='blue'> **Plainfield Lakes** </font> https://pubs.usgs.gov/publication/sir20225046/full

# %%
import geopandas as gp ; import flopy as fp ; import mfsetup     ; import os ; import numpy as np ; import matplotlib.pyplot as plt ; import yaml ; import pyproj ; from pathlib import Path     
import pandas as pd ; import rasterio    ; from rasterio.plot import show ; import shutil         ; from mfsetup import MF6model; _R=Path("./_R");_R.mkdir(exist_ok=True)
#MFSETUP=Path("./_R/MFSETUP");MFSETUP.mkdir(exist_ok=True)                       ; PP = Path('E:/15_REPOS/02_Beta-Me/mfsetup/Beta_data/plainfieldlakes')   ; DO = Path(PP/'DO')

# %%
m = MF6model.setup_from_yaml('pfl_nwt_test.yml')
# Out:
# loading configuration file pfl_nwt_test.yml...
#
# Setting up pfl model from configuration in pfl_nwt_test.yml
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 m = MF6model.setup_from_yaml('pfl_nwt_test.yml')
#
# File c:\Users\gross.DESKTOP-AIRQM2M\anaconda3\envs\mfsetup\Lib\site-packages\mfsetup\mfmodel.py:1808, in MFsetupMixin.setup_from_yaml(cls, yamlfile, verbose)
#    1795 """Make a model from scratch, using information in a yamlfile.
#    1796
#    1797 Parameters
#    (...)   1805 m : model instance
#    1806 """
#    1807 cfg = cls.load_cfg(yamlfile, verbose=verbose)
# -> 1808 return cls.setup_from_cfg(cfg, verbose=verbose)
#
# File c:\Users\gross.DESKTOP-AIRQM2M\anaconda3\envs\mfsetup\Lib\site-packages\mfsetup\mfmodel.py:1831, in MFsetupMixin.setup_from_cfg(cls, cfg, verbose)
#    1828 print(msg)
#    1829 t0 = time.time()
# -> 1831 m = cls(cfg=cfg) #, **kwargs)
#    1833 # make a grid if one isn't already specified
#    1834 if 'grid' not in m.cfg.keys():
#
# File c:\Users\gross.DESKTOP-AIRQM2M\anaconda3\envs\mfsetup\Lib\site-packages\mfsetup\mf6model.py:65, in MF6model.__init__(self, simulation, modelname, parent, cfg, exe_name, load, version, lgr, **kwargs)
#      63 if not isinstance(cfg, dict):
#      64     cfg = self.load_cfg(cfg)
# ---> 65 cfg = self._parse_model_kwargs(cfg)
#      66 defaults.update(cfg['model'])
#      67 kwargs = {k: v for k, v in kwargs.items() if k not in defaults}
#
# File c:\Users\gross.DESKTOP-AIRQM2M\anaconda3\envs\mfsetup\Lib\site-packages\mfsetup\mf6model.py:1070, in MF6model._parse_model_kwargs(cfg)
#    1067 @staticmethod
#    1068 def _parse_model_kwargs(cfg):
# -> 1070     if isinstance(cfg['model']['simulation'], str):
#    1071         # assume that simulation for model
#    1072         # is the one simulation specified in configuration
#    1073         # (regardless of the name specified in model configuration)
#    1074         cfg['model']['simulation'] = cfg['simulation']
#    1075     if isinstance(cfg['model']['simulation'], dict):
#    1076         # create simulation from simulation block in config dict
#
# KeyError: 'simulation'

# %%
domain = gp.read_file(PP/'source_data'/'all_lakes.shp')                                                                  ; epsg = pyproj.CRS(domain.crs).to_epsg() 
bounds = domain.geometry[0].bounds                 ; TX,TY = bounds[2]+1000-bounds[0]  ,bounds[3]+1000-bounds[1]         
dx = 50 ; dy = dx   ; xcells = int(np.ceil(TX/dx)) ; ycells = int(np.ceil(TY/dy))                                       ; print('epsg:',epsg,'Dimentions:',int(TX),int(TY), xcells*ycells)

# %%
#%%capture
m = mfsetup.MF6model.setup_from_yaml(PP/'pfl_nwt.yml')         # YML a01 _______________________________ 'E:/15_REPOS/02_Beta-Me/data/Nerversink/Domain/Model_Extent_HUC12.shp'          
#m.dis.idomain.array.sum() * 5                              ; m.dis.export(Path("../PA_DIS")/'neverskink{}m.dis.shp'.format(dx))

# %%
TY

# %% [markdown]
# <font color='orange'> **MFSETUP __________________________________________________** </font> <br>
# <font color='orange'> **DIS __________________________________________________** </font>

# %%
'''%%capture
m = mfsetup.MF6model.setup_from_yaml(_R/'a02.yml')         # YML a01 _______________________________ 'E:/15_REPOS/02_Beta-Me/data/Nerversink/Domain/Model_Extent_HUC12.shp'          
m.dis.idomain.array.sum() * 5                              ; m.dis.export(Path("../PA_DIS")/'neverskink{}m.dis.shp'.format(dx))      # 1:30' '''

# %% [markdown]
# <font color='orange'> **WELLS __________________________________________________** </font>

# %%
# old___________________________________________  E:\15_REPOS\02_Beta-Me\data\Nerversink\a01.yml
IY['setup_grid']['xoff'] = bounds[0]        ; IY['dis']['griddata']['delc']   = dx          ; IY['setup_grid']['yoff'] = bounds[1]       
IY['dis']['griddata']['delr'] = dy          ; IY['dis']['dimensions']['nlay'] = 1           ; IY['dis']['dimensions']['nrow'] = ycells      ; IY['dis']['dimensions']['ncol'] = xcells
with open(_R/'a02.yml', 'w') as ofp:           yaml.dump(IY, ofp)                           # new___________________________________________  a02.yml
