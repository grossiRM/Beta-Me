# %% [markdown]
# **aa**

# %%
import matplotlib.pyplot as pt ;import numpy as np ; import gstools as gs; from gstools.random import MasterRNG ; import matplotlib.pyplot as plt ; import pandas as pd 
from pathlib import Path       ;TA=Path("./TA");TA.mkdir(exist_ok=True)  ;import pyvista as pvv     #pip install --upgrade trame-vtk trame-vuetify ipywidgets ... "pyvista[jupyter]"
import os; import sys; sys.path.append('E:/15_REPOS/g00_gstools-herten-example/Beta_tools')         #; from vtk2gslib import vtk2numpy    
cond = np.array([2.50e-04,2.30e-04,6.10e-05,2.60e-02,1.30e-01,9.50e-02,4.30e-05,6.00e-07,2.30e-03,1.40e-04,])

REF1 = Path('E:/15_REPOS/00_BETAMI/02_floPy/_R/11') ; REF2 = Path('E:/15_REPOS/02_Beta-Me/data/VTK')   

# https://geostat-framework.readthedocs.io/projects/gstools/en/v1.0.1/tutorial_03_vario.html
# https://geostat-framework.readthedocs.io/projects/gstools/en/stable/examples/00_misc/04_herten.html        # https://docs.paraview.org/en/v6.0.1/ReferenceManual/vtkNumPyIntegration.html

# %%
#MESH = pvv.read(REF1/'HK.vtk')       #; MESH.plot(style='wireframe',show_edges=True) #print(MESH,type)
MESH = pvv.read(REF2/'section1.vtk')  ; POINTS = MESH.points ; CELL = MESH.cell_data   ; pd.DataFrame(POINTS).to_csv(TA/'POINTS.csv')  # 300 MB
MESH.plot(style='wireframe',cmap="terrain") #print(MESH,type)
POINTS.shape
# Out:
# Widget(value='<iframe src="http://localhost:64459/index.html?ui=P_0x194bdbf5110_7&reconnect=auto" class="pyvis…
# (44800, 3)
