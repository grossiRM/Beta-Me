# %% [markdown]
# <font color='blue'> **06 __________________________________ Variogram_Model __ 02** </font>

# %%
import os; import sys ; from pathlib import Path  
file_path = Path('E:/15_REPOS/05_Working/11e_Kriging_Beta/05_GeostatsPy_____')
os.startfile(file_path/'02__Experimental_variogram_calculation_.ipynb')
